# %%
import plotly
plotly.__version__
# Out:
# '2.5.1'

# %%
import json
import pandas as pd
import sys
import os

from sodapy import Socrata

# %%
# get plotly credentials
PLOTLY_USERNAME = os.environ.get('PLOTLY_USERNAME')
PLOTLY_API_KEY = os.environ.get('PLOTLY_API_KEY')

# %%
# set plotly credentials
plotly.tools.set_credentials_file(username=PLOTLY_USERNAME, api_key=PLOTLY_API_KEY)

# %%
# get Mapbox access token
MAPBOX_ACCESS_TOKEN = os.environ.get('MAPBOX_ACCESS_TOKEN')

# %% [markdown]
# ## Get data
# We're grabbing [Film locations in San Francisco, CA](https://opendata.socrata.com/Fun/Film-locations-in-San-Francisco-with-Geo/ge6u-xxyt) using the sodapy python client for the Socrata Open Data API.
# Search for more open data [here](https://opendata.socrata.com/).

# %%
# configure request
domain = 'opendata.socrata.com'
resource = 'ge6u-xxyt'
client = Socrata(domain, None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# get data using Socrata Open Data API
json_data = json.dumps(client.get(resource, content_type='json'))
df = pd.read_json(json_data)
df.head(5)
# Out:
#              actor1            actor2         actor3          director  \
# 0               NaN               NaN            NaN   Ryan K. Whiting
# 1     James Stewart         Kim Novak            NaN  Alfred Hitchcock
# 2        Dean Jones       Michele Lee      Ed Harris  Robert Stevenson
# 3  Malcolm McDowell  Mary Steenburgen  Ellyn Burstyn    Nicholas Meyer
# 4    Robin Williams       Sally Field            NaN    Chris Columbus
#
#                               distributor  \
# 0                                     NaN
# 1                      Paramount Pictures
# 2                Buena Vista Distribution
# 3      Columbia Broadcasting System (CBS)
# 4  Twentieth Century Fox Film Corporation
#
#                                                facts  \
# 0                                                NaN
# 1  Tennis courts now sit on the site; in the movi...
# 2  Lombard Street is not actually the crookedest ...
# 3                                                NaN
# 4                                                NaN
#
#                                  location  \
# 0              0-100 block Halleck Street
# 1                       1007 Gough Street
# 2             100 Block of Lombard Street
# 3  100 Block of Union Street (Cow Hollow)
# 4                  100 Embarcadero Street
#
#                                           location_1  \
# 0  {u'latitude': u'37.7937113', u'needs_recoding'...
# 1  {u'latitude': u'37.7825466', u'needs_recoding'...
# 2  {u'latitude': u'37.802139', u'needs_recoding':...
# 3  {u'latitude': u'37.7980175', u'needs_recoding'...
# 4  {u'latitude': u'37.7933939', u'needs_recoding'...
#
#                         productioncompany  release  \
# 0                               RKW Films     2010
# 1         Alfred J. Hitchcock Productions     1958
# 2                 Walt Disney Productions     1968
# 3                    Orion Pictures Corp.     1979
# 4  Twentieth Century Fox Film Corporation     1993
#
#                          title              writer
# 0  Broken-A Modern Love Story      Ryan K. Whiting
# 1                      Vertigo         Alec Coppel
# 2                 The Love Bug          Bill Walsh
# 3              Time After Time      Karl Alexander
# 4               Mrs. Doubtfire  Randi Mayem Singer

# %%
# parse dict in the location_1 column
loc_df = df['location_1'].apply(pd.Series)
loc_df.head(5)
# Out:
#                                        human_address    latitude  \
# 0  {"address":"0-100 block Halleck Street","city"...  37.7937113
# 1  {"address":"1007 Gough Street","city":"San Fra...  37.7825466
# 2  {"address":"100 Block of Lombard Street","city...   37.802139
# 3  {"address":"100 Block of Union Street (Cow Hol...  37.7980175
# 4  {"address":"100 Embarcadero Street","city":"Sa...  37.7933939
#
#       longitude  needs_recoding
# 0  -122.4000974           False
# 1  -122.4241443           False
# 2    -122.41874           False
# 3  -122.4350625           False
# 4  -122.3925928           False

# %%
# join dataframes
final_df = df.join(loc_df)
final_df.head(5)
# Out:
#              actor1            actor2         actor3          director  \
# 0               NaN               NaN            NaN   Ryan K. Whiting
# 1     James Stewart         Kim Novak            NaN  Alfred Hitchcock
# 2        Dean Jones       Michele Lee      Ed Harris  Robert Stevenson
# 3  Malcolm McDowell  Mary Steenburgen  Ellyn Burstyn    Nicholas Meyer
# 4    Robin Williams       Sally Field            NaN    Chris Columbus
#
#                               distributor  \
# 0                                     NaN
# 1                      Paramount Pictures
# 2                Buena Vista Distribution
# 3      Columbia Broadcasting System (CBS)
# 4  Twentieth Century Fox Film Corporation
#
#                                                facts  \
# 0                                                NaN
# 1  Tennis courts now sit on the site; in the movi...
# 2  Lombard Street is not actually the crookedest ...
# 3                                                NaN
# 4                                                NaN
#
#                                  location  \
# 0              0-100 block Halleck Street
# 1                       1007 Gough Street
# 2             100 Block of Lombard Street
# 3  100 Block of Union Street (Cow Hollow)
# 4                  100 Embarcadero Street
#
#                                           location_1  \
# 0  {u'latitude': u'37.7937113', u'needs_recoding'...
# 1  {u'latitude': u'37.7825466', u'needs_recoding'...
# 2  {u'latitude': u'37.802139', u'needs_recoding':...
# 3  {u'latitude': u'37.7980175', u'needs_recoding'...
# 4  {u'latitude': u'37.7933939', u'needs_recoding'...
#
#                         productioncompany  release  \
# 0                               RKW Films     2010
# 1         Alfred J. Hitchcock Productions     1958
# 2                 Walt Disney Productions     1968
# 3                    Orion Pictures Corp.     1979
# 4  Twentieth Century Fox Film Corporation     1993
#
#                          title              writer  \
# 0  Broken-A Modern Love Story      Ryan K. Whiting
# 1                      Vertigo         Alec Coppel
# 2                 The Love Bug          Bill Walsh
# 3              Time After Time      Karl Alexander
# 4               Mrs. Doubtfire  Randi Mayem Singer
#
#                                        human_address    latitude  \
# 0  {"address":"0-100 block Halleck Street","city"...  37.7937113
# 1  {"address":"1007 Gough Street","city":"San Fra...  37.7825466
# 2  {"address":"100 Block of Lombard Street","city...   37.802139
# 3  {"address":"100 Block of Union Street (Cow Hol...  37.7980175
# 4  {"address":"100 Embarcadero Street","city":"Sa...  37.7933939
#
#       longitude  needs_recoding
# 0  -122.4000974           False
# 1  -122.4241443           False
# 2    -122.41874           False
# 3  -122.4350625           False
# 4  -122.3925928           False

# %% [markdown]
# ## Visualize data

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = Data([
    Scattermapbox(
        lat=final_df['latitude'].tolist(),
        lon=final_df['longitude'].tolist(),
        mode='markers',
        marker=Marker(
            size=9
        ),
        text=final_df['title'].tolist(),
    )
])
layout = Layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=MAPBOX_ACCESS_TOKEN,
        bearing=0,
        center=dict(
            lat=37.7648,
            lon=-122.463
        ),
        pitch=40,
        zoom=10
    ),
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='Multiple Mapbox')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~misenerm/0 or inside your plot.ly account where it is named 'Multiple Mapbox'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~misenerm/0.embed" height="525px" width="100%"></iframe>
